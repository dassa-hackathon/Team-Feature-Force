# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('train_data.csv')
df.head()
# Out:
#   Period Code Cycle ID      B_2      B_3  B_4     B_5    B_9   B_10 B_14  \
# 0           1        1  -0.0007  -0.0004  100  518.67  14.62  21.61  1.3
# 1           1        3  -0.0043   0.0003  100  518.67  14.62  21.61  1.3
# 2           1        4   0.0007        0  100  518.67  14.62  21.61  1.3
# 3           1        5  -0.0019  -0.0002  100  518.67  14.62  21.61  1.3
# 4           1        6  -0.0043  -0.0001  100  518.67  14.62  21.61  1.3
#
#     B_15  ...     B_18    B_19  B_20 B_21  B_22 B_23   B_24     B_25  \
# 0  47.47  ...  8138.62  8.4195  0.03  392  2388  100  39.06   23.419
# 1  47.27  ...  8133.23  8.4178  0.03  390  2388  100  38.95  23.3442
# 2  47.13  ...  8133.83  8.3682  0.03  392  2388  100  38.88  23.3739
# 3  47.28  ...   8133.8  8.4294  0.03  393  2388  100   38.9  23.4044
# 4  47.16  ...  8132.85  8.4108  0.03  391  2388  100  38.98  23.3669
#
#           timestamp Good/Bad
# 0  03/01/2020 00:00        0
# 1  03/01/2020 00:10        0
# ...

# %%
df
# Out:
#       Period Code Cycle ID      B_2      B_3  B_4     B_5    B_9   B_10 B_14  \
# 0               1        1  -0.0007  -0.0004  100  518.67  14.62  21.61  1.3
# 1               1        3  -0.0043   0.0003  100  518.67  14.62  21.61  1.3
# 2               1        4   0.0007        0  100  518.67  14.62  21.61  1.3
# 3               1        5  -0.0019  -0.0002  100  518.67  14.62  21.61  1.3
# 4               1        6  -0.0043  -0.0001  100  518.67  14.62  21.61  1.3
# ...           ...      ...      ...      ...  ...     ...    ...    ...  ...
# 15169         NaN      179   0.0051   0.0003  100  518.67  14.62  21.61  1.3
# 15170         NaN      186  -0.0034  -0.0003  100  518.67  14.62  21.61  1.3
# 15171         NaN      192    0.003   0.0001  100  518.67  14.62  21.61  1.3
# 15172         NaN      198  -0.0044   0.0002  100  518.67  14.62  21.61  1.3
# 15173         NaN      276   0.0009  -0.0005  100  518.67  14.62  21.61  1.3
#
# ...

# %%
df.describe()
# Out:
#            Good/Bad
# count  15174.000000
# mean       0.150718
# std        0.357786
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df.isnull().sum()
# Out:
# Period Code    23
# Cycle ID       33
# B_2            38
# B_3            33
# B_4            33
# B_5            31
# B_9            32
# B_10           40
# B_14           33
# B_15           39
# B_16           34
# B_17           34
# B_18           34
# B_19           28
# B_20           29
# B_21           29
# B_22           28
# B_23           24
# B_24           36
# B_25           35
# timestamp       0
# Good/Bad        0
# dtype: int64

# %%
df1=df.dropna()
df1.shape
# Out:
# (14549, 22)

# %%
df1
# Out:
#       Period Code Cycle ID      B_2      B_3  B_4     B_5    B_9   B_10 B_14  \
# 0               1        1  -0.0007  -0.0004  100  518.67  14.62  21.61  1.3
# 1               1        3  -0.0043   0.0003  100  518.67  14.62  21.61  1.3
# 2               1        4   0.0007        0  100  518.67  14.62  21.61  1.3
# 3               1        5  -0.0019  -0.0002  100  518.67  14.62  21.61  1.3
# 4               1        6  -0.0043  -0.0001  100  518.67  14.62  21.61  1.3
# ...           ...      ...      ...      ...  ...     ...    ...    ...  ...
# 15146        stop      151   0.0051  -0.0004  100  518.67  14.62  21.61  1.3
# 15147        stop      163  -0.0005  -0.0003  100  518.67  14.62  21.61  1.3
# 15148        stop      172  -0.0007   0.0002  100  518.67  14.62  21.61  1.3
# 15149        stop      206  -0.0014        0  100  518.67  14.62  21.61  1.3
# 15150        stop  Missing   0.0007        0  100  518.67  14.62  21.61  1.3
#
# ...

# %%
corr_matrix = df1.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
df2=df1.iloc[:,2:20]

# %%
corr_matrix = df2.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/0v/jwfk5rf54j31r251dzgfvvsh0000gn/T/ipykernel_24641/1738479396.py in <module>
#       1 corr_matrix = df2.corr()
#       2 plt.figure(figsize=(12, 10))
# ----> 3 sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
#       4 plt.title('Correlation Heatmap')
#       5 plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
# ...

# %%
df2
# Out:
#            B_2      B_3  B_4     B_5    B_9   B_10 B_14   B_15    B_16  \
# 0      -0.0007  -0.0004  100  518.67  14.62  21.61  1.3  47.47  521.66
# 1      -0.0043   0.0003  100  518.67  14.62  21.61  1.3  47.27  522.42
# 2       0.0007        0  100  518.67  14.62  21.61  1.3  47.13  522.86
# 3      -0.0019  -0.0002  100  518.67  14.62  21.61  1.3  47.28  522.19
# 4      -0.0043  -0.0001  100  518.67  14.62  21.61  1.3  47.16  521.68
# ...        ...      ...  ...     ...    ...    ...  ...    ...     ...
# 15146   0.0051  -0.0004  100  518.67  14.62  21.61  1.3  47.33  522.28
# 15147  -0.0005  -0.0003  100  518.67  14.62  21.61  1.3   47.7  520.32
# 15148  -0.0007   0.0002  100  518.67  14.62  21.61  1.3  47.91  520.85
# 15149  -0.0014        0  100  518.67  14.62  21.61  1.3  47.37  522.12
# 15150   0.0007        0  100  518.67  14.62  21.61  1.3  47.54  521.67
#
#           B_17     B_18    B_19  B_20 B_21  B_22 B_23   B_24     B_25
# ...

# %%
correlation_matrix = df2.corr()

# Create a correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap for Specified Columns')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/0v/jwfk5rf54j31r251dzgfvvsh0000gn/T/ipykernel_24641/2524565081.py in <module>
#       3 # Create a correlation heatmap
#       4 plt.figure(figsize=(10, 8))
# ----> 5 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
#       6 plt.title('Correlation Heatmap for Specified Columns')
#       7 plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
constant_columns = df2.columns[df2.nunique() == 1]
if not df2.empty and len(constant_columns) < len(df2.columns):
    # Compute the correlation matrix for the specified columns
    correlation_matrix = df2.corr()

    # Create a correlation heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
    plt.title('Correlation Heatmap for Specified Columns')
    plt.show()
else:
    print("No valid data for correlation analysis. Check for missing or constant columns.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/0v/jwfk5rf54j31r251dzgfvvsh0000gn/T/ipykernel_24641/2101291102.py in <module>
#       6     # Create a correlation heatmap
#       7     plt.figure(figsize=(10, 8))
# ----> 8     sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
#       9     plt.title('Correlation Heatmap for Specified Columns')
#      10     plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
if not df2.empty and len(df2) > 1:
    # Compute the correlation matrix for the specified columns
    correlation_matrix = df2.corr()

    # Create a correlation heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
    plt.title('Correlation Heatmap for Specified Columns')
    plt.show()
else:
    print("Insufficient data to compute correlations. Check your DataFrame for missing or constant columns.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/0v/jwfk5rf54j31r251dzgfvvsh0000gn/T/ipykernel_24641/3417334550.py in <module>
#       5     # Create a correlation heatmap
#       6     plt.figure(figsize=(10, 8))
# ----> 7     sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
#       8     plt.title('Correlation Heatmap for Specified Columns')
#       9     plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
df1.dtypes
# Out:
# Period Code    object
# Cycle ID       object
# B_2            object
# B_3            object
# B_4            object
# B_5            object
# B_9            object
# B_10           object
# B_14           object
# B_15           object
# B_16           object
# B_17           object
# B_18           object
# B_19           object
# B_20           object
# B_21           object
# B_22           object
# B_23           object
# B_24           object
# B_25           object
# timestamp      object
# Good/Bad        int64
# dtype: object

# %%
df2.head(25)
# Out:
#         B_2      B_3  B_4     B_5    B_9   B_10     B_14   B_15    B_16  \
# 0   -0.0007  -0.0004  100  518.67  14.62  21.61      1.3  47.47  521.66
# 1   -0.0043   0.0003  100  518.67  14.62  21.61      1.3  47.27  522.42
# 2    0.0007        0  100  518.67  14.62  21.61      1.3  47.13  522.86
# 3   -0.0019  -0.0002  100  518.67  14.62  21.61      1.3  47.28  522.19
# 4   -0.0043  -0.0001  100  518.67  14.62  21.61      1.3  47.16  521.68
# 5    0.0008   0.0001  100  518.67  14.62  21.61      1.3  47.29  521.79
# 6    0.0018  -0.0003  100  518.67  14.62  21.61      1.3  47.15   521.4
# 7   -0.0019   0.0004  100  518.67  14.62  21.61      1.3  47.38  521.85
# 8   -0.0018  -0.0003  I/O  518.67  14.62  21.61      1.3   47.3   start
# 9    0.0006   0.0005  100  518.67  14.62  21.61      1.3  47.24  521.49
# 10  -0.0031  -0.0001  100  518.67  14.62  21.61      1.3  47.21  521.76
# 11   0.0032  -0.0003  100  518.67  14.62  21.61      1.3   47.4  521.89
# ...

# %%
columns_to_convert = ['B_2', 'B_3', 'B_4', 'B_5', 'B_9', 'B_10', 'B_14', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_20', 'B_21', 'B_22', 'B_23', 'B_24', 'B_25']

# Convert the specified columns to float, handling non-numeric values with 'coerce'
for column in columns_to_convert:
    df2[column] = pd.to_numeric(df2[column], errors='coerce')

df2.dtypes
# Out:
# B_2     float64
# B_3     float64
# B_4     float64
# B_5     float64
# B_9     float64
# B_10    float64
# B_14    float64
# B_15    float64
# B_16    float64
# B_17    float64
# B_18    float64
# B_19    float64
# B_20    float64
# B_21    float64
# B_22    float64
# B_23    float64
# B_24    float64
# B_25    float64
# dtype: object

# %%
correlation_matrix = df2.corr()

# Create a correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap for Specified Columns')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already created the df2 DataFrame

# Compute the correlation matrix for the specified columns
correlation_matrix = df2.corr()

# Set a larger figure size for the heatmap
plt.figure(figsize=(12, 10))

# Create a correlation heatmap with larger font sizes
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 12}, linewidths=0.5)

# Customize the color palette, if desired
# sns.set_palette("Blues")

plt.title('Correlation Heatmap for Specified Columns', size=14)

# Show the plot
plt.show()

# %%
df2['B_17'].value_counts()
# Out:
# 2388.08    798
# 2388.09    792
# 2388.10    780
# 2388.07    775
# 2388.11    766
# 2388.12    764
# 2388.06    708
# 2388.05    673
# 2388.14    661
# 2388.04    658
# 2388.13    648
# 2388.03    578
# 2388.15    568
# 2388.02    563
# 2388.01    489
# 2388.16    452
# 2388.00    409
# 2388.17    388
# 2387.99    311
# 2388.18    295
# 2388.19    276
# 2387.98    248
# 2388.20    218
# 2388.21    178
# 2388.22    157
# 2388.23    152
# 2387.97    140
# 2387.96    122
# 2388.24    117
# 2388.25     91
# 2388.26     86
# 2388.27     79
# 2387.95     71
# 2388.28     70
# 2388.29     47
# 2387.94     37
# 2388.30     32
# 2388.31     23
# 2388.32     19
# 2388.33     16
# 2387.93     13
# 2387.92      8
# 2388.34      5
# 2388.35      4
# 2388.36      4
# 2388.37      3
# 2387.91      2
# 2388.39      2
# 2387.88      1
# 2387.89      1
# 2387.90      1
# Name: B_17, dtype: int64

# %%
df3 = df2.drop(['B_4', 'B_5', 'B_9','B_14','B_20','B_22','B_23'], axis=1)
df3.shape
# Out:
# (14549, 11)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already created the df2 DataFrame

# Compute the correlation matrix for the specified columns
corr_matrix = df3.corr()

# Set a larger figure size for the heatmap
plt.figure(figsize=(12, 10))

# Create a correlation heatmap with larger font sizes
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 12}, linewidths=0.5)

# Customize the color palette, if desired
# sns.set_palette("Blues")

plt.title('Correlation Heatmap for Specified Columns', size=14)

# Show the plot
plt.show()

# %%
corr_matrix
# Out:
#            B_2       B_3      B_10      B_15      B_16      B_17      B_18  \
# B_2   1.000000  0.012415  0.000790  0.016563 -0.001516  0.000115 -0.001417
# B_3   0.012415  1.000000  0.015273  0.013268 -0.012214  0.020537 -0.012047
# B_10  0.000790  0.015273  1.000000  0.157969 -0.155463  0.158075 -0.003689
# B_15  0.016563  0.013268  0.157969  1.000000 -0.846833  0.784785  0.155350
# B_16 -0.001516 -0.012214 -0.155463 -0.846833  1.000000 -0.790126 -0.089427
# B_17  0.000115  0.020537  0.158075  0.784785 -0.790126  1.000000 -0.161806
# B_18 -0.001417 -0.012047 -0.003689  0.155350 -0.089427 -0.161806  1.000000
# B_19  0.009893  0.016592  0.147112  0.780375 -0.766416  0.699262  0.184159
# B_21  0.006275  0.010800  0.131798  0.723688 -0.705580  0.628012  0.232045
# B_24 -0.005698 -0.010510 -0.142099 -0.770608  0.750109 -0.684183 -0.182512
# B_25 -0.009811 -0.008800 -0.131747 -0.774060  0.755897 -0.690473 -0.186391
#
#           B_19      B_21      B_24      B_25
# ...

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Assuming you have already created the df3 DataFrame

# Step 1: Standardize the data
scaler = StandardScaler()
df3_scaled = scaler.fit_transform(df3_imputed)

# Step 2: Create a PCA model
pca = PCA()

# Step 3: Fit the model to the standardized data
pca.fit(df3_scaled)

# Step 4: Get the sorted eigenvalues and eigenvectors
eigenvalues = pca.explained_variance_
eigenvectors = pca.components_

# Step 5: Select the number of components (e.g., 2 components for demonstration)
num_components = 2

# Step 6: Project the data onto the selected principal components
reduced_data = pca.transform(df3_scaled)[:, :num_components]

# The 'reduced_data' DataFrame contains the data reduced to the specified number of principal components
reduced_data
# Out:
# array([[-2.09939806,  0.04138758],
#        [-2.76033285, -0.63257141],
#        [-2.9439754 , -0.55069041],
#        ...,
#        [ 2.7184915 ,  0.4542119 ],
#        [-1.34761635, -0.22255511],
#        [-0.24193123, -0.64667169]])

# %%
from sklearn.impute import SimpleImputer

# Assuming you have already created the df3 DataFrame
# Initialize and fit the imputer
imputer = SimpleImputer(strategy='mean')
df3_imputed = imputer.fit_transform(df3)

# %%
import matplotlib.pyplot as plt

# Assuming you have already obtained the 'reduced_data' DataFrame
# Assuming you have selected the first two principal components

# Create a scatter plot of the first two principal components
plt.figure(figsize=(8, 6))
plt.scatter(reduced_data[:, 0], reduced_data[:, 1], alpha=0.5)
plt.title('PCA Scatter Plot')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)

# Show the plot
plt.show()

# %%
# Assuming you have already created the df3 DataFrame
df3_dropped = df3.dropna()

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Assuming you have the 'df3' DataFrame with your data

# Step 1: Standardize the data
scaler = StandardScaler()
df3_scaled = scaler.fit_transform(df3_dropped)

# Step 2: Create a PCA model with the number of components you want
num_components = 2  # You can change this to any desired number of components
pca = PCA(n_components=num_components)

# Step 3: Fit the PCA model to the standardized data
reduced_data = pca.fit_transform(df3_scaled)

# Create a DataFrame for the reduced data
df_reduced = pd.DataFrame(data=reduced_data, columns=[f'Principal Component {i+1}' for i in range(num_components)])

# Plot the reduced data
plt.figure(figsize=(8, 6))
plt.scatter(df_reduced['Principal Component 1'], df_reduced['Principal Component 2'], alpha=0.5)
plt.title('PCA Scatter Plot (Reduced Data)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# %%
df4=df1.iloc[:,2:]

df4.drop(['timestamp'],inplace=True,axis=1)
df4.head()
# Out:
#        B_2      B_3  B_4     B_5    B_9   B_10 B_14   B_15    B_16     B_17  \
# 0  -0.0007  -0.0004  100  518.67  14.62  21.61  1.3  47.47  521.66  2388.02
# 1  -0.0043   0.0003  100  518.67  14.62  21.61  1.3  47.27  522.42  2388.03
# 2   0.0007        0  100  518.67  14.62  21.61  1.3  47.13  522.86  2388.08
# 3  -0.0019  -0.0002  100  518.67  14.62  21.61  1.3  47.28  522.19  2388.04
# 4  -0.0043  -0.0001  100  518.67  14.62  21.61  1.3  47.16  521.68  2388.03
#
#       B_18    B_19  B_20 B_21  B_22 B_23   B_24     B_25  Good/Bad
# 0  8138.62  8.4195  0.03  392  2388  100  39.06   23.419         0
# 1  8133.23  8.4178  0.03  390  2388  100  38.95  23.3442         0
# 2  8133.83  8.3682  0.03  392  2388  100  38.88  23.3739         0
# 3   8133.8  8.4294  0.03  393  2388  100   38.9  23.4044         0
# 4  8132.85  8.4108  0.03  391  2388  100  38.98  23.3669         0

# %%
df4['Good/Bad'].value_counts()
# Out:
# 0    12358
# 1     2191
# Name: Good/Bad, dtype: int64

# %%
df4 = df4.drop(['B_4', 'B_5', 'B_9','B_14','B_20','B_22','B_23'], axis=1)
df4
# Out:
#            B_2      B_3   B_10   B_15    B_16     B_17     B_18    B_19 B_21  \
# 0      -0.0007  -0.0004  21.61  47.47  521.66  2388.02  8138.62  8.4195  392
# 1      -0.0043   0.0003  21.61  47.27  522.42  2388.03  8133.23  8.4178  390
# 2       0.0007        0  21.61  47.13  522.86  2388.08  8133.83  8.3682  392
# 3      -0.0019  -0.0002  21.61  47.28  522.19  2388.04   8133.8  8.4294  393
# 4      -0.0043  -0.0001  21.61  47.16  521.68  2388.03  8132.85  8.4108  391
# ...        ...      ...    ...    ...     ...      ...      ...     ...  ...
# 15146   0.0051  -0.0004  21.61  47.33  522.28  2388.04   8143.3  8.4173  390
# 15147  -0.0005  -0.0003  21.61   47.7  520.32  2388.08  8167.53  8.4599  395
# 15148  -0.0007   0.0002  21.61  47.91  520.85  2388.15  8154.66  8.4583  396
# 15149  -0.0014        0  21.61  47.37  522.12  2388.08  8138.66  8.4326  393
# 15150   0.0007        0  21.61  47.54  521.67  2388.14  8135.71   8.439  393
#
#         B_24     B_25  Good/Bad
# ...

# %%
corr_matrix = df4.corr()

# Set a larger figure size for the heatmap
plt.figure(figsize=(12, 10))

# Create a correlation heatmap with larger font sizes
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 12}, linewidths=0.5)

# Customize the color palette, if desired
# sns.set_palette("Blues")

plt.title('Correlation Heatmap for Specified Columns', size=14)

# Show the plot
plt.show()

# %%
columns_to_convert = ['B_2', 'B_3', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_21', 'B_24', 'B_25']

# Convert the specified columns to float, handling non-numeric values with 'coerce'
for column in columns_to_convert:
    df4[column] = pd.to_numeric(df4[column], errors='coerce')

# %%
X = df4.drop('Good/Bad', axis=1)
y = df4['Good/Bad']

# Standardize the feature data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 3: Perform PCA
num_components = 2
pca = PCA(n_components=num_components)
X_pca = pca.fit_transform(X_scaled)

# Create a DataFrame for the reduced data
df_pca = pd.DataFrame(data=X_pca, columns=[f'Principal Component {i+1}' for i in range(num_components)])

# Step 4: Create scatterplots with different categories (Good/Bad)
plt.figure(figsize=(10, 5))

# Scatterplot for 'Good' (category 0)
plt.subplot(1, 2, 1)
plt.scatter(
    df_pca[y == 0]['Principal Component 1'],
    df_pca[y == 0]['Principal Component 2'],
    label='Good',
    alpha=0.5
)
plt.title('PCA Scatter Plot for Good')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()

# Scatterplot for 'Bad' (category 1)
plt.subplot(1, 2, 2)
plt.scatter(
    df_pca[y == 1]['Principal Component 1'],
    df_pca[y == 1]['Principal Component 2'],
    label='Bad',
    alpha=0.5
)
plt.title('PCA Scatter Plot for Bad')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /var/folders/0v/jwfk5rf54j31r251dzgfvvsh0000gn/T/ipykernel_24641/1473183105.py:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_pca[y == 0]['Principal Component 1'],
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# /var/folders/0v/jwfk5rf54j31r251dzgfvvsh0000gn/T/ipykernel_24641/1473183105.py in <module>
#      20 plt.subplot(1, 2, 1)
#      21 plt.scatter(
# ---> 22     df_pca[y == 0]['Principal Component 1'],
#      23     df_pca[y == 0]['Principal Component 2'],
#      24     label='Good',
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3013         # Do we have a (boolean) 1d indexer?
#    3014         if com.is_bool_indexer(key):
# -> 3015             return self._getitem_bool_array(key)
#    3016
# ...

# %%
df4['B_3'].value_counts()
# Out:
# -0.0003    1455
#  0.0001    1454
# -0.0004    1440
#  0.0000    1437
#  0.0003    1426
#  0.0002    1419
# -0.0001    1403
# -0.0002    1395
#  0.0004    1363
#  0.0005     752
# -0.0005     675
#  0.0006      49
# -0.0006      29
# Name: B_3, dtype: int64

# %%
df4 = df4.apply(pd.to_numeric, errors='coerce')
df4 = df4.dropna()

# %%
# Assuming you have already loaded your data into df4

# Reset the index of the DataFrame
df4 = df4.reset_index(drop=True)

# Now, you can filter rows based on the 'Good/Bad' column
X = df4.drop('Good/Bad', axis=1)
y = df4['Good/Bad']

# Continue with your PCA and scatterplot code as previously provided.

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 3: Perform PCA
num_components = 2
pca = PCA(n_components=num_components)
X_pca = pca.fit_transform(X_scaled)

# Create a DataFrame for the reduced data
df_pca = pd.DataFrame(data=X_pca, columns=[f'Principal Component {i+1}' for i in range(num_components)])

# Step 4: Create scatterplots with different categories (Good/Bad)
plt.figure(figsize=(10, 5))

# Scatterplot for 'Good' (category 0)
plt.subplot(1, 2, 1)
plt.scatter(
    df_pca[y == 0]['Principal Component 1'],
    df_pca[y == 0]['Principal Component 2'],
    label='Good',
    alpha=0.5
)
plt.title('PCA Scatter Plot for Good')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()

# Scatterplot for 'Bad' (category 1)
plt.subplot(1, 2, 2)
plt.scatter(
    df_pca[y == 1]['Principal Component 1'],
    df_pca[y == 1]['Principal Component 2'],
    label='Bad',
    alpha=0.5
)
plt.title('PCA Scatter Plot for Bad')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Assuming df4 is your DataFrame with the 'Good/Bad' and other categorical features

# Create a contingency table
contingency_table = pd.crosstab(df4['B_21'], df4['Good/Bad'])

# Perform the chi-square test
chi2, p, _, _ = chi2_contingency(contingency_table)

# Output the results
print("Chi-Square Value:", chi2)
print("P-value:", p)

# Interpret the results
if p < 0.05:  # You can choose the significance level (alpha) here
    print("The two variables are dependent (associated).")
else:
    print("The two variables are independent (not associated).")
# Out:
# Chi-Square Value: 5551.288900686139
# P-value: 0.0
# The two variables are dependent (associated).

# %%
# !pip install imbalanced-learn
# Out:
# ...
#      |████████████████████████████████| 235 kB 8.4 MB/s eta 0:00:01
# ...

# %%
df4
# Out:
#           B_2     B_3   B_10   B_15    B_16     B_17     B_18    B_19   B_21  \
# 0     -0.0007 -0.0004  21.61  47.47  521.66  2388.02  8138.62  8.4195  392.0
# 1     -0.0043  0.0003  21.61  47.27  522.42  2388.03  8133.23  8.4178  390.0
# 2      0.0007  0.0000  21.61  47.13  522.86  2388.08  8133.83  8.3682  392.0
# 3     -0.0019 -0.0002  21.61  47.28  522.19  2388.04  8133.80  8.4294  393.0
# 4     -0.0043 -0.0001  21.61  47.16  521.68  2388.03  8132.85  8.4108  391.0
# ...       ...     ...    ...    ...     ...      ...      ...     ...    ...
# 12035  0.0051 -0.0004  21.61  47.33  522.28  2388.04  8143.30  8.4173  390.0
# 12036 -0.0005 -0.0003  21.61  47.70  520.32  2388.08  8167.53  8.4599  395.0
# 12037 -0.0007  0.0002  21.61  47.91  520.85  2388.15  8154.66  8.4583  396.0
# 12038 -0.0014  0.0000  21.61  47.37  522.12  2388.08  8138.66  8.4326  393.0
# 12039  0.0007  0.0000  21.61  47.54  521.67  2388.14  8135.71  8.4390  393.0
#
#         B_24     B_25  Good/Bad
# ...

# %%
from imblearn.over_sampling import SMOTE
X = df4.drop(columns=['Good/Bad'])  # Features
y = df4['Good/Bad']  # Target variable
# Create an instance of the SMOTE class
smote = SMOTE(sampling_strategy='auto', random_state=42)

# Fit and resample the dataset
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Split the resampled data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Create an XGBoost classifier
model = xgb.XGBClassifier(random_state=42)

# Train the model on the training data
model.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = model.predict(X_test)

# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# Print the results
print(f"Accuracy: {accuracy}")
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.9755620723362659
# Confusion Matrix:
#  [[1984   63]
#  [  37 2008]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98      2047
#            1       0.97      0.98      0.98      2045
#
#     accuracy                           0.98      4092
#    macro avg       0.98      0.98      0.98      4092
# weighted avg       0.98      0.98      0.98      4092

# %%
df_test=pd.read_csv('test_data1.csv')
df_test.drop(columns=["B_4", "B_5", "B_9", "B_10", "B_14", "B_20", "B_22", "B_23"], inplace=True)
numeric_columns = ['B_2', 'B_3', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_21', 'B_24', 'B_25']
for col in numeric_columns:
    df_test[col] = pd.to_numeric(df_test[col], errors='coerce')   
test2 = df_test.drop(columns = ["Period Code", "Cycle ID", "timestamp"])
test2.fillna(0,inplace=True)
test2.head()
# Out:
#       B_2     B_3   B_15    B_16     B_17     B_18    B_19   B_21   B_24  \
# 0 -0.0014 -0.0003  47.28  521.83  2388.04  8158.04  8.4314  393.0  39.07
# 1 -0.0003  0.0003  47.35  521.84  2388.02  8154.69  8.3897  391.0  38.80
# 2 -0.0020  0.0000  47.20  522.02  2388.01  8152.23  8.4298  392.0  38.87
# 3  0.0000 -0.0002  47.40  521.67  2388.00  8158.26  8.4078  391.0  39.02
# 4 -0.0011  0.0003  47.31  521.80  2388.01  8154.09  8.4490  391.0  38.89
#
#       B_25
# 0  23.2800
# 1  23.3672
# 2  23.3531
# 3  23.2821
# 4  23.2888

# %%
pred=model.predict(test2)
new_df = pd.DataFrame({'ID': df_test['timestamp'].astype(str) + '-' + df_test['Cycle ID'].astype(str)})
new_df['Good/Bad'] = pred
new_df.to_csv("subm.csv", index=False)

# %%
y_resampled.value_counts()
# Out:
# 0    10229
# 1    10229
# Name: Good/Bad, dtype: int64

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

param_dist = {
    'n_estimators': randint(100, 1000),
    'max_depth': randint(3, 10),
    'learning_rate': uniform(0.01, 0.3)
}

random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist, n_iter=100, cv=5, scoring='accuracy', n_jobs=-1, random_state=42)
random_search.fit(X_train, y_train)

best_params = random_search.best_params_
best_estimator = random_search.best_estimator_

print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'learning_rate': 0.052277267492428794, 'max_depth': 9, 'n_estimators': 912}

# %%
import xgboost as xgb

# New best hyperparameters
new_best_hyperparameters = {
    'learning_rate': 0.052277267492428794,
    'max_depth': 9,
    'n_estimators': 912
}

# Create an XGBoost model with the new best hyperparameters
new_best_model = xgb.XGBClassifier(random_state=42, **new_best_hyperparameters)

# Train the model with the training data
new_best_model.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = new_best_model.predict(X_test)

# Evaluate the model's accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy with New Best Model: {accuracy}")
# Out:
# Accuracy with New Best Model: 0.9728739002932552

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# New best hyperparameters
new_best_hyperparameters = {
    'learning_rate': 0.052277267492428794,
    'max_depth': 9,
    'n_estimators': 912
}

# Create an XGBoost model using XGBClassifier with the new best hyperparameters
new_best_model = XGBClassifier(
    learning_rate=new_best_hyperparameters['learning_rate'],
    max_depth=new_best_hyperparameters['max_depth'],
    n_estimators=new_best_hyperparameters['n_estimators'],
    random_state=42
)

# Train the model with the training data
new_best_model.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = new_best_model.predict(X_test)

# Evaluate the model's accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy with New Best Model (XGBClassifier): {accuracy}")
# Out:
# Accuracy with New Best Model (XGBClassifier): 0.9728739002932552

# %%
pred2=new_best_model.predict(test2)
new_df = pd.DataFrame({'ID': df_test['timestamp'].astype(str) + '-' + df_test['Cycle ID'].astype(str)})
new_df['Good/Bad'] = pred2
new_df.to_csv("subm7.csv", index=False)
